# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import pandas as pd
import cohorts
from cohorts.functions import missense_snv_count
from query_tcga import cohort, config
from query_tcga import query_tcga as qtcga
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config.set_value(USE_CACHE=True)
config.set_value(GDC_TOKEN_PATH='/Users/jacquelineburos/Downloads/gdc-user-token.2016-09-26T12-23-27-04-00.txt')
config.set_value(GDC_DATA_DIR='/Users/jacquelineburos/projects/tcga-blca/data/gdc/')
## to test, run:
# config.get_setting_value('GDC_TOKEN_PATH')

# %%
clin = qtcga.get_clinical_data(project_name='TCGA-BLCA', n=2)

# %%
clin.head().transpose()
# Out:
#                                                                                       0  \
# _source_desc                          /Users/jacquelineburos/projects/tcga-blca/data...
# _source_file_uuid                                [33ab4a7a-0481-4a6d-91df-392bd1bcd2a3]
# _source_type                                                                        XML
# ajcc_metastasis_pathologic_pm                                                        M0
# ajcc_nodes_pathologic_pn                                                             N0
# ajcc_pathologic_tumor_stage                                                   Stage III
# ajcc_staging_edition                                                                6th
# ajcc_tumor_clinical_ct                                                               TX
# ajcc_tumor_pathologic_pt                                                            T3a
# anatomic_organ_subdivision                                                Bladder - NOS
# birth_days_to                                                                    -25259
# case_id                                            25eaf3f9-c364-423c-aaae-925e7b393afc
# death_days_to                                                                       NaN
# ethnicity                                                        NOT HISPANIC OR LATINO
# extracapsular_extension                                                             NaN
# followup_lost_to                                                                     NO
# form_completion_day                                                                  30
# form_completion_month                                                                 1
# form_completion_year                                                               2015
# gender                                                                             MALE
# height_cm_at_diagnosis                                                              168
# histologic_diagnosis                  Muscle invasive urothelial carcinoma (pT2 or a...
# histologic_subtype                                                        Non-Papillary
# history_neoadjuvant_treatment                                                        No
# history_other_malignancy                                                             No
# incidental_prostate_cancer_indicator                                                 NO
# initial_pathologic_dx_days_to                                                         0
# initial_pathologic_dx_year                                                         2007
# karnofsky_score                                                                      90
# last_contact_days_to                                                               2886
# ...                                                                                 ...
# new_tumor_event_dx_days_to                                                          NaN
# new_tumor_event_dx_indicator                                                         NO
# new_tumor_event_pharmaceutical_tx                                                   NaN
# new_tumor_event_radiation_tx                                                        NaN
# new_tumor_event_site                                                                NaN
# new_tumor_event_site_other                                                          NaN
# new_tumor_event_surgery                                                             NaN
# new_tumor_event_type                                                                NaN
# noninvasive_bladder_history                                                          NO
# occupation_current                                                              Retired
# occupation_primary                                                                  NaN
# occupation_primary_industry                                                         NaN
# occupation_primary_years_worked                                                     NaN
# patient_consent_status                                                              YES
# patient_id                                                                         A9KQ
# pharmaceutical_tx_adjuvant                                                           NO
# prospective_collection                                                               NO
# race                                                                              WHITE
# radiation_treatment_adjuvant                                                         NO
# retrospective_collection                                                            YES
# submitted_tumor_site                                                            Bladder
# tobacco_smoking_age_started                                                         NaN
# tobacco_smoking_history_indicator                                                     1
# tobacco_smoking_pack_years_smoked                                                   NaN
# treatment_outcome_at_tcga_followup                                    Complete Response
# treatment_outcome_first_course                              Complete Remission/Response
# tumor_grade                                                                  High Grade
# tumor_status                                                                 TUMOR FREE
# vital_status                                                                      Alive
# weight_kg_at_diagnosis                                                               72
#
#                                                                                       1
# _source_desc                          /Users/jacquelineburos/projects/tcga-blca/data...
# _source_file_uuid                                [6082fbb4-1f13-4e58-a0fb-33574354b74b]
# _source_type                                                                        XML
# ajcc_metastasis_pathologic_pm                                                        M0
# ajcc_nodes_pathologic_pn                                                             N1
# ajcc_pathologic_tumor_stage                                                    Stage IV
# ajcc_staging_edition                                                                6th
# ajcc_tumor_clinical_ct                                                              NaN
# ajcc_tumor_pathologic_pt                                                             T3
# anatomic_organ_subdivision                                               Wall Posterior
# birth_days_to                                                                    -23323
# case_id                                            dd3a6357-9087-44b2-9956-f981e0de6f1c
# death_days_to                                                                       734
# ethnicity                                                        NOT HISPANIC OR LATINO
# extracapsular_extension                                                              NO
# followup_lost_to                                                                     NO
# form_completion_day                                                                  23
# form_completion_month                                                                10
# form_completion_year                                                               2014
# gender                                                                             MALE
# height_cm_at_diagnosis                                                              173
# histologic_diagnosis                  Muscle invasive urothelial carcinoma (pT2 or a...
# histologic_subtype                                                        Non-Papillary
# history_neoadjuvant_treatment                                                        No
# history_other_malignancy                                                             No
# incidental_prostate_cancer_indicator                                                 NO
# initial_pathologic_dx_days_to                                                         0
# initial_pathologic_dx_year                                                         2008
# karnofsky_score                                                                      80
# last_contact_days_to                                                                678
# ...                                                                                 ...
# new_tumor_event_dx_days_to                                                          651
# new_tumor_event_dx_indicator                                                        YES
# new_tumor_event_pharmaceutical_tx                                                    NO
# new_tumor_event_radiation_tx                                                        YES
# new_tumor_event_site                                                    Lymph Node Only
# new_tumor_event_site_other                                                      Adrenal
# new_tumor_event_surgery                                                              NO
# new_tumor_event_type                              Locoregional (Urothelial tumor event)
# noninvasive_bladder_history                                                          NO
# occupation_current                                                           unemployed
# occupation_primary                                                    mechanical fitter
# occupation_primary_industry                                                construction
# occupation_primary_years_worked                                                      36
# patient_consent_status                                                              YES
# patient_id                                                                         A9KO
# pharmaceutical_tx_adjuvant                                                           NO
# prospective_collection                                                               NO
# race                                                                              WHITE
# radiation_treatment_adjuvant                                                         NO
# retrospective_collection                                                            YES
# submitted_tumor_site                                                            Bladder
# tobacco_smoking_age_started                                                          20
# tobacco_smoking_history_indicator                                                     2
# tobacco_smoking_pack_years_smoked                                                    69
# treatment_outcome_at_tcga_followup                                  Progressive Disease
# treatment_outcome_first_course                                      Progressive Disease
# tumor_grade                                                                  High Grade
# tumor_status                                                                 WITH TUMOR
# vital_status                                                                       Dead
# weight_kg_at_diagnosis                                                               65
#
# [65 rows x 2 columns]

# %%
blca_patients = cohort.prep_cohort_patients(project_name='TCGA-BLCA')
blca_cohort = cohort.prep_cohort(patients=blca_patients)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-16-d7f3b4505d78> in <module>()
# ----> 1 blca_patients = cohort.prep_cohort_patients(project_name='TCGA-BLCA')
#       2 blca_cohort = cohort.prep_cohort(patients=blca_patients)
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/cohort.pyc in prep_cohort_patients(project_name, include_vcfs, n, **kwargs)
#      77     """ Given a project_name, return a list of cohorts.Patient objects
#      78     """
# ---> 79     clin = qt.get_clinical_data(project_name=project_name, n=n, **kwargs)
#      80     vcf_fileinfo = None
#      81     if not n and include_vcfs:
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/log_with.pyc in wrapper(*args, **kwds)
#      26             self.logger.debug(self.ENTRY_MESSAGE.format(func.__name__))  # logging level .info(). Set to .debug() if you want to
#      27             self.logger.debug(dict(**kwds))
# ---> 28             f_result = func(*args, **kwds)
#      29             self.logger.debug(self.EXIT_MESSAGE.format(func.__name__))   # logging level .info(). Set to .debug() if you want to
#      30             return f_result
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/query_tcga.pyc in get_clinical_data(project_name, **kwargs)
#     488 @log_with()
#     489 def get_clinical_data(project_name, **kwargs):
# --> 490     xml_files = download_clinical_files(project_name=project_name, **kwargs)
#     491     data = list()
#     492     for xml_file in xml_files:
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/log_with.pyc in wrapper(*args, **kwds)
#      26             self.logger.debug(self.ENTRY_MESSAGE.format(func.__name__))  # logging level .info(). Set to .debug() if you want to
#      27             self.logger.debug(dict(**kwds))
# ---> 28             f_result = func(*args, **kwds)
#      29             self.logger.debug(self.EXIT_MESSAGE.format(func.__name__))   # logging level .info(). Set to .debug() if you want to
#      30             return f_result
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/query_tcga.pyc in download_clinical_files(project_name, n, data_dir, **kwargs)
#     323     """
#     324     ## update kwargs with parameters listed explicitly above (for readability)
# --> 325     return download_files(project_name=project_name, data_category=['Clinical'], n=n, data_dir=data_dir, **kwargs)
#     326
#     327 #### ---- verify downloaded files ----
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/log_with.pyc in wrapper(*args, **kwds)
#      26             self.logger.debug(self.ENTRY_MESSAGE.format(func.__name__))  # logging level .info(). Set to .debug() if you want to
#      27             self.logger.debug(dict(**kwds))
# ---> 28             f_result = func(*args, **kwds)
#      29             self.logger.debug(self.EXIT_MESSAGE.format(func.__name__))   # logging level .info(). Set to .debug() if you want to
#      30             return f_result
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/query_tcga.pyc in download_files(project_name, data_category, n, data_dir, query_args, only_updates, verify, size, pages)
#     296     finally:
#     297         manifest_file.close()
# --> 298     fileinfo = api.get_fileinfo_data(file_id=helpers.convert_to_file_id(downloaded))
#     299     downloaded.fileinfo = fileinfo ## set attribute on returned list
#     300     return downloaded
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/api.pyc in get_fileinfo_data(file_id, fields, chunk_size)
#      90     if len(file_id)>chunk_size:
#      91         chunks = [file_id[x:x+chunk_size] for x in range(0, len(file_id), chunk_size)]
# ---> 92         data = [get_fileinfo_data(chunk, fields=fields) for chunk in chunks]
#      93         return pd.concat(data)
#      94     res = get_fileinfo(file_id=file_id, fields=fields, format='json')
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/api.pyc in get_fileinfo_data(file_id, fields, chunk_size)
#      92         data = [get_fileinfo_data(chunk, fields=fields) for chunk in chunks]
#      93         return pd.concat(data)
# ---> 94     res = get_fileinfo(file_id=file_id, fields=fields, format='json')
#      95     df = list()
#      96     for hit in res:
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/log_with.pyc in wrapper(*args, **kwds)
#      26             self.logger.debug(self.ENTRY_MESSAGE.format(func.__name__))  # logging level .info(). Set to .debug() if you want to
#      27             self.logger.debug(dict(**kwds))
# ---> 28             f_result = func(*args, **kwds)
#      29             self.logger.debug(self.EXIT_MESSAGE.format(func.__name__))   # logging level .info(). Set to .debug() if you want to
#      30             return f_result
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/api.pyc in get_fileinfo(file_id, fields, format)
#      76 def get_fileinfo(file_id, fields=get_setting_value('DEFAULT_FILE_FIELDS'), format=None):
#      77     query_args = {'files.file_id': file_id}
# ---> 78     response = get_data(endpoint_name='files', query_args=query_args, fields=fields, format=format)
#      79     if format == 'json':
#      80         return response.json()['data']['hits']
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/log_with.pyc in wrapper(*args, **kwds)
#      26             self.logger.debug(self.ENTRY_MESSAGE.format(func.__name__))  # logging level .info(). Set to .debug() if you want to
#      27             self.logger.debug(dict(**kwds))
# ---> 28             f_result = func(*args, **kwds)
#      29             self.logger.debug(self.EXIT_MESSAGE.format(func.__name__))   # logging level .info(). Set to .debug() if you want to
#      30             return f_result
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/api.pyc in get_data(endpoint_name, arg, project_name, fields, size, page, data_category, query_args, verify, *args, **kwargs)
#      49
#      50     # requests URL-encodes automatically
# ---> 51     response = requests_get(endpoint, params=params)
#      52     response.raise_for_status()
#      53     return response
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/cache.pyc in rateLimitedFunction(*args, **kargs)
#      16             if leftToWait>0:
#      17                 time.sleep(leftToWait)
# ---> 18             ret = func(*args,**kargs)
#      19             lastTimeCalled[0] = time.clock()
#      20             return ret
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/query_tcga/cache.pyc in requests_get(*args, **kwargs)
#      28         requests_cache.install_cache(cache_name='github_cache', backend='sqlite', expire_after=180)
#      29
# ---> 30
#      31 @RateLimited(1)
#      32 def requests_get(*args, **kwargs):
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /Users/jacquelineburos/anaconda3/envs/python27/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     451
#     452         except (ProtocolError, socket.error) as err:
# --> 453             raise ConnectionError(err, request=request)
#     454
#     455         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', error(54, 'Connection reset by peer'))

# %% [markdown]
# ## retrieve dataframe for a cohort

# %%
df = blca_cohort.as_dataframe()
df.describe()

# %% [markdown]
# ## plot survival

# %%
blca_cohort.plot_survival(on='tobacco_smoking_history_indicator')

# %%
blca_cohort.plot_survival(on='tobacco_smoking_history_indicator', threshold=1)

# %%
blca_cohort.plot_survival(on='tobacco_smoking_history_indicator', threshold=1, how='pfs')

# %% [markdown]
# You can also pass a function to the `plot_survival` method.
#
# For example, let's say we wanted to summarized survival according to the tumor grade.
#
# First, we create a function to classify our tumor type:

# %%
def high_grade_tumor(row):
    return row['tumor_grade'] == 'High Grade'

# %% [markdown]
# We then pass this function to the `plot_survival` method.
#
# (Behind the scenes, the function will be applied to each `row` of our dataframe & the result will be summarized.)

# %%
blca_cohort.plot_survival(on=high_grade_tumor, how='pfs')

# %% [markdown]
# ## Summarizing somatic mutation burden

# %%
blca_cohort.plot_survival(missense_snv_count)
